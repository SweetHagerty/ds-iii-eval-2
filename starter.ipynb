# %% [markdown]
# # Hagerty Insurance — Renewal by Lead Source (starter)
#
# This notebook is just here to get you past setup — it loads the three tables and shows a quick peek so you can start thinking about the problem instead of about file paths. **Everything past the peek is yours.** There's no prescribed path, and no need to keep or use these cells as written; rework them however you like.
#
# **Where we're starting:** *which lead sources bring in the policyholders most likely to renew?*
#
# That's deliberately open-ended. Feel free to ask questions, and say any assumptions out loud as you go — talking through your thinking is the most useful part of this for both of us.

# %%
import pandas as pd
import numpy as np

# Three tables, exported from different systems.
policies      = pd.read_csv("policies.csv", parse_dates=["inception_date"])
policy_events = pd.read_csv("policy_events.csv", parse_dates=["event_date"])
vehicle_risk  = pd.read_csv("vehicle_risk.csv")

# %%
# A quick peek so you know what you're working with.
for name, df in [("policies", policies), ("policy_events", policy_events), ("vehicle_risk", vehicle_risk)]:
    print(f"{name}: {df.shape[0]:,} rows x {df.shape[1]} cols")

policies.head()

# %%
policy_events.head()

# %%
vehicle_risk.head()

# %% [markdown]
# ---
# ## Your turn
#
# A good first milestone is an initial per-source read you'd feel comfortable walking us through — we can build from there together.
#
# It's usually worth getting oriented to what each table contains and how they relate before diving in. Beyond that, go wherever your judgment takes you.
